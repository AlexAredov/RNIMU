# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexAredov/RNIMU/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# K-mean

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import csv
import matplotlib.ticker as ticker

def is_number(str):
    try:
        float(str)
        return True
    except ValueError:
        return False

x = []
y = []
z = []
iii = 0

with open('./drive/MyDrive/Данные.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row[0])
        if is_number(row[0]):
            x.append(float(row[0]))
            y.append(iii)
            iii+=1
            z.append(0)


data = list(zip(x,z))
#print(data)

#K-means
kmeans = KMeans(n_clusters=6)
kmeans.fit(data)

data = list(zip(x,y))

fig, ax = plt.subplots(figsize=(15, 6))
plt.scatter(x, y, c=kmeans.labels_)
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
#ax.xaxis.set_major_locator(ticker.MultipleLocator(50))
#ax.xaxis.set_minor_locator(ticker.MultipleLocator(10))

#ax.yaxis.set_major_locator(ticker.MultipleLocator(50))
#ax.yaxis.set_minor_locator(ticker.MultipleLocator(10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#ax.grid(which='major',
#        color = 'gray',
#        linewidth = 0.5)

#ax.minorticks_on()
#ax.grid(which='minor',
#        color = 'gray',
#        linewidth = 0.5)

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-7-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      99 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     100   """Mount your Google Drive at the specified mountpoint path."""
# --> 101   return _mount(
#     102       mountpoint,
#     103       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     122       'TBE_EPHEM_CREDS_ADDR'] if ephemeral else _os.environ['TBE_CREDS_ADDR']
#     123   if ephemeral:
# --> 124     _message.blocking_request(
# ...

# %% [markdown]
# SpectralClustering

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import csv
import numpy as np
import matplotlib.ticker as ticker
from sklearn.cluster import SpectralClustering
from sklearn.metrics import calinski_harabasz_score

def is_number(str):
    try:
        float(str)
        return True
    except ValueError:
        return False

x = []
y = []
z = []
iii = 0

with open('./drive/MyDrive/Данные.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row[0])
        if is_number(row[0]):
            x.append(float(row[0]))
            y.append(iii)
            iii+=1
            z.append(0)

data = list(zip(x,z))


model = SpectralClustering(n_clusters=6,gamma=0.01)
model.fit(data)
score = calinski_harabasz_score(data,model.labels_)
#SpectralClustering

data = list(zip(x,y))

pre_y = model.labels_

fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

for i in range(6):
    plt.scatter(np.array(data)[pre_y==i][:,0],np.array(data)[pre_y==i][:,1])
plt.show()

# %% [markdown]
# Иерархическая кластеризация

# %%
import matplotlib.pyplot as plt
import csv
import matplotlib.ticker as ticker
from sklearn.cluster import AgglomerativeClustering


def is_number(str):
    try:
        float(str)
        return True
    except ValueError:
        return False

x = []
y = []
z = []
iii = 0

with open('./drive/MyDrive/Данные.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row[0])
        if is_number(row[0]):
            x.append(float(row[0]))
            y.append(iii)
            iii+=1
            z.append(0)


data = list(zip(x,z))
#print(data)

cluster = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')
cluster.fit_predict(data)

data = list(zip(x,y))

fig, ax = plt.subplots(figsize=(15, 6))
plt.scatter(np.array(data)[:,0],np.array(data)[:,1], c=cluster.labels_, cmap='rainbow')
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# Сравнение

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#К-средних
plt.scatter(x, y, c=kmeans.labels_)
plt.show()

fig, ax = plt.subplots(figsize=(15, 6))
#Иерарх
plt.scatter(np.array(data)[:,0],np.array(data)[:,1], c=cluster.labels_, cmap='rainbow')
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dc379ae08832> in <module>
#       5 plt.yticks(fontsize=12)
#       6 #К-средних
# ----> 7 plt.scatter(x, y, c=kmeans.labels_)
#       8 plt.show()
#       9
#
# NameError: name 'kmeans' is not defined

# %% [markdown]
# x и y

# %% [markdown]
# K-means

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import csv
import matplotlib.ticker as ticker

def is_number(str):
    try:
        float(str)
        return True
    except ValueError:
        return False

x = []
y = []

with open('./drive/MyDrive/kmeans_blobs.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row[0])
        if is_number(row[1]) and is_number(row[2]):
            x.append(float(row[1]))
            y.append(float(row[2]))


data = list(zip(x,y))
#print(data)

#K-means
kmeans = KMeans(n_clusters=6)
kmeans.fit(data)

fig, ax = plt.subplots(figsize=(15, 6))
plt.scatter(x, y, c=kmeans.labels_)
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# Spectral

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import csv
import numpy as np
import matplotlib.ticker as ticker
from sklearn.cluster import SpectralClustering
from sklearn.metrics import calinski_harabasz_score

def is_number(str):
    try:
        float(str)
        return True
    except ValueError:
        return False

x = []
y = []

with open('./drive/MyDrive/kmeans_blobs.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row[0])
        if is_number(row[1]) and is_number(row[2]):
            x.append(float(row[1]))
            y.append(float(row[2]))

data = list(zip(x,y))


model = SpectralClustering(n_clusters=6,gamma=0.01)
model.fit(data)
score = calinski_harabasz_score(data,model.labels_)
#SpectralClustering

data = list(zip(x,y))

pre_y = model.labels_

fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

for i in range(6):
    plt.scatter(np.array(data)[pre_y==i][:,0],np.array(data)[pre_y==i][:,1])
plt.show()

# %% [markdown]
# Иерарх

# %%
import matplotlib.pyplot as plt
import csv
import matplotlib.ticker as ticker
import numpy as np
from sklearn.cluster import AgglomerativeClustering


def is_number(str):
    try:
        float(str)
        return True
    except ValueError:
        return False

x = []
y = []

with open('./drive/MyDrive/kmeans_blobs.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row[0])
        if is_number(row[1]) and is_number(row[2]):
            x.append(float(row[1]))
            y.append(float(row[2]))


data = list(zip(x,y))
#print(data)

cluster = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')
cluster.fit_predict(data)

fig, ax = plt.subplots(figsize=(15, 6))
plt.scatter(np.array(data)[:,0],np.array(data)[:,1], c=cluster.labels_, cmap='rainbow')
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# Сравнение

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#Спектры
for i in range(6):
    plt.scatter(np.array(data)[pre_y==i][:,0],np.array(data)[pre_y==i][:,1])
plt.show()


fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#К-средних
plt.scatter(x, y, c=kmeans.labels_)
plt.show()

fig, ax = plt.subplots(figsize=(15, 6))
#Иерарх
plt.scatter(np.array(data)[:,0],np.array(data)[:,1], c=cluster.labels_, cmap='rainbow')
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import csv
import numpy as np
import matplotlib.ticker as ticker
from sklearn.cluster import SpectralClustering
from sklearn.metrics import calinski_harabasz_score
from sklearn.mixture import GaussianMixture

def is_number(str):
    try:
        float(str)
        return True
    except ValueError:
        return False

x = []
y = []
z = []
iii = 0

with open('./drive/MyDrive/Данные.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row[0])
        if is_number(row[0]):
            x.append(float(row[0]))
            y.append(iii)
            iii+=1
            z.append(0)

data = list(zip(x,z))


gm = GaussianMixture(n_components=6, random_state=0).fit(data)
print(gm.means_[0][0])

data = list(zip(x,y))

pre_y = gm.means_

fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

labels = gm.predict(data)
plt.scatter(np.array(data)[:,0],np.array(data)[:,1], c=labels, cmap='rainbow')
plt.show()
# Out:
# 11.333653414476558

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#К-средних
plt.scatter(x, y, c=kmeans.labels_)
plt.show()

fig, ax = plt.subplots(figsize=(15, 6))
#Иерарх
plt.scatter(np.array(data)[:,0],np.array(data)[:,1], c=cluster.labels_, cmap='rainbow')
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

#Плотность
fig, ax = plt.subplots(figsize=(15, 6))
ax.set_xlabel(r'val', fontsize=14)
ax.set_ylabel(r'ID', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

labels = gm.predict(data)
plt.scatter(np.array(data)[:,0],np.array(data)[:,1], c=labels, cmap='rainbow')
plt.show()
